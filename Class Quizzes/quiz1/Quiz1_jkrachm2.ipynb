# %%
## Hi, my name is Joshua Krachman. I will be loading in the first three lines of specific CSV data.

import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/jkrachm2/Data-Science/master/Master%20Repo/ds4bme_intro-master/data/kirby127a_3_1_ax_283Labels_M2_corrected_stats.csv")
df.head(3)
# Out:
#    Unnamed: 0                 rawid              roi  ...      std  type  level
# 0           1  kirby127a_3_1_ax.img  Telencephalon_L  ...  51.8593     1      1
# 1           2  kirby127a_3_1_ax.img  Telencephalon_R  ...  53.6471     1      1
# 2           3  kirby127a_3_1_ax.img   Diencephalon_L  ...  32.2733     1      1
#
# [3 rows x 10 columns]
